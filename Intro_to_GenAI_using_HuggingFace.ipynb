# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadipalli-Sandeep/GenerativeAI-Using-HuggingFace/blob/main/Intro_to_GenAI_using_HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries
# !pip install langchain-huggingface
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 14.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
#call secret key
from google.colab import userdata
sec_key = userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %%
#Access HuggingFace Model using API
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key = userdata.get("HUGGINGFACEHUB_API_TOKEN")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm = HuggingFaceEndpoint(repo_id = repo_id, max_length = 128, temperature = 0.7, token = sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke('What is Deep Learning ?')
# Out:
# '\n\nDeep learning is a subset of machine learning that uses artificial neural networks with representation learning. It is inspired by the structure and function of the brain, specifically the interconnected network of neurons that can process and transmit information.\n\nDeep learning algorithms can automatically learn features from data, rather than relying on hand-engineered features, making them more effective for handling large and complex datasets. They can be used for a variety of tasks, including image and speech recognition, natural language processing, and autonomous driving.\n\nDeep learning models consist of multiple layers of interconnected neurons, each of which performs a simple computation on the input data. The output of one layer is used as the input to the next layer, allowing the network to learn increasingly complex representations of the data as it progresses through the layers. This is in contrast to traditional machine learning models, which often rely on sim
# ...

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id = repo_id, max_length = 128, temperature = 0.7, token = sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("What is Prompt Engineering")
# Out:
# "?\n\nPrompt engineering is a technique used in the field of natural language processing (NLP) to design and optimize prompts, or input sentences, for machine learning models to generate high-quality, coherent, and contextually appropriate responses. The goal of prompt engineering is to guide the model to produce the desired output by providing it with a well-structured and informative prompt. This technique is often used in conversation models, such as chatbots, and has gained popularity with the rise of large language models like ChatGPT.\n\nEffective prompt engineering involves understanding the model's capabilities and limitations, as well as the context and intent of the desired output. It requires a combination of creativity, technical knowledge, and a deep understanding of human language and communication. By carefully crafting prompts, developers can improve the performance, efficiency, and usability of NLP models, making them more useful and accessible to a wider audience.\n
# ...

# %%
from langchain import PromptTemplate, LLMChain
question = "Who won the cricket world cup in the year 2011?"
template = """ Question : {question}
Answer : Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=['question'])
print(prompt)
# Out:
# input_variables=['question'] template=" Question : {question}\nAnswer : Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm, prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# {'question': 'Who won the cricket world cup in the year 2011?', 'text': "\n\nFirst, we need to determine the year. Since we're asked for the year 2011, that's the year in question.\n\nNext, we need to find out which team won the cricket World Cup in 2011. The 2011 Cricket World Cup was held in India, Sri Lanka, and Bangladesh from February 19 to April 2, 2011. The final match was played on April 2, 2011, at the Wankhede Stadium in Mumbai, India. The teams that made it to the final were India and Sri Lanka. India won the match by 6 wickets, becoming the champions of the 2011 Cricket World Cup.\n\nSo, the answer to your question is India, who won the cricket World Cup in the year 2011."}

# %%
#hugging face pipeline
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens = 100)
hf = HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7a48acdfe050>)

# %%
hf.invoke("What is deep learning?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'What is deep learning?\n\nDeep learning is "human" thought, using data collected from machines, including brain waves, to determine what is necessary and what is undesirable. Deep learning, like other natural mental processes, relies on our brains for guidance.\n\nAnd there are two different kinds of neural processing going on in a person\'s brain. (This is important for better understanding the psychology of thinking.) Each is called a memory. In the mind of someone who is learning, these things can be used. But if'

# %%
#use huggingface using gpu
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=0,  # replace with device_map="auto" to use the accelerate library.
    pipeline_kwargs={"max_new_tokens": 100},
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain = prompt | gpu_llm

# %%
question="What is Generative AI?"
chain.invoke({"question":question})
# Out:
# "Question: What is Generative AI?\n\nAnswer: Let's think step by step. Suppose we want to build something. Then create an example where, if we find that it exists, then I want something to be generated. We can think about the following in an entirely different way: suppose we want to create a character from a character that was generated by a computer that knows how to calculate how much it is worth to create a single character for our game. (We have two options for this, you can specify an attribute, a variable, or a class), as well as we"
